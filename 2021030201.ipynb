# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2021/blob/main/2021030201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [중앙값 구하기(Find The Median)](https://min7014.github.io/math20210302001.html)

# %% [markdown]
# ### [참고]
# Geogebra와 수학의 시각화 책의 가상주사위 만들기를 참고하여 수업에 실제 적용함.
#
# [Geogebra와 수학의 시각화](https://www.geogebra.org/m/gsARCQs5)

# %% [markdown]
# **[영문버전]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     **첫번째 아래방향 --> Sort by --> Construction order**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. Input 에
#
#     **Data={5,28,28,29,29,30,31,31,32}**
#
#     입력하여 Data라는 list를 만든다.
#
# 04. Input 에
#
#     **SortedD=Sort[Data]**
#
#     입력하여 Data를 오름차순으로 정렬한 SortedD라는  list를 만든다.
#
#
#
# 05. Input 에
#
#     **TotalNumberOfD=CountIf[x==x,Data]**
#
#     입력하여 TotalNumberOfD라는 수를 만든다.
#
#
#
# 06. Input 에
#
#     **Judgement1=If[Mod[TotalNumberOfD,2]==1,"Since the number of Data is odd " ,"Since the number of Data is even"]**
#
#     입력하여 Judgement1이라는 Text를 만든다.
#
#
#
# 07. Input 에
#
#     **Judgement2=If[Mod[TotalNumberOfD,2]==1, ((TotalNumberOfD-1)/2+1) "th number ", "The average of the " (TotalNumberOfD/2) "nd and " (TotalNumberOfD/2+1) "rd numbers "] "in the SortedD(sorted Data) is the median."**
#
#     입력하여 Judgement2라는 Text를 만든다.
#
#
#
# 08. Input 에
#
#     **MedianD=If[Mod[TotalNumberOfD,2]==1, (Element[SortedD,(TotalNumberOfD-1)/2+1]) ,(Element[SortedD,TotalNumberOfD/2]+Element[SortedD,TotalNumberOfD/2+1])/2 ]**
#
#     **Judgement3="Therefore, the median value is " MedianD "."**
#
#     입력하여 MedianD라는 수와 Judgement3이라는 Text를 만든다.
#
# 09. Data의 개수가 홀수이면 가운데 위치한 값이 중앙값이 됨을 확인한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10. Input에
#
#     **Data={2, 18, 22, 28}**
#
#    ** 입력하여 기본 자료의 바꾼다.**
#
# 11. 자료의 개수가 짝수이면 가운데 위치한 두 값의 평균이 중앙값이 됨을 확인한다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12. Input에
#
#     **AverageOfD=mean[Data]**
#
#     입력한다.
#
#
#
# 13. AverageOfD과 MedianData를 비교해 본다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14. Input에
#
#     **MedianFunctionOfGeogebra=Median[Data]**
#
# 15. Geogebra에도 중앙값 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성함.

# %% [markdown]
# ex)
#
#   **Data={3, 7, 5, 4, 1, 9}**
#
#   **Data={24, 151, 135, 146, 122}**
#
#   **Data={36, 55, 49, 7, 28, 40}**
#
#   **Data={86, 88, 74, 92, 80, 105, 102, 95, 89, 96, 120, 201, 113, 107, 97}**

# %% [markdown]
# **[한글버전]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     첫번째 아래방향을 선택 --> 정렬기준 --> 구성순서를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. 입력창에
#
#     **자료={5,28,28,29,29,30,31,31,32}**
#
#     입력하여 자료라는 리스트를 만든다.
#
#
#
# 04. 입력창에
#
#     **정렬된자료=정렬[자료]**
#
#     입력하여 자료를 오름차순으로 정렬한 정렬된자료라는  리스트를 만든다.
#
#
#
# 05. 입력창에
#
#     **자료전체개수=세기조건[x==x,자료]**
#
#     입력하여 자료전체개수라는 수를 만든다.
#
#
#
# 06. 입력창에
#
#     **판단1=조건[나머지[자료전체개수,2]==1,"자료의 개수가 홀수이므로 " ,"자료의 개수가 짝수이므로"]**
#
#     입력하여 판단1이라는 텍스트를 만든다.
#
#
#
# 07. 입력창에
#
#     **판단2="정렬된 자료의 "  조건[나머지[자료전체개수,2]==1, ((자료전체개수-1)/2+1) "번째 수가 중앙값이다.",(자료전체개수/2) "번째 수와 " (자료전체개수/2+1) "번째 수의 평균이 중앙값이다."]**
#
#     입력하여 판단2라는 텍스트를 만든다.
#
#
#
# 08. 입력창에
#
#     **자료중앙값=조건[나머지[자료전체개수,2]==1, (원소[정렬된자료,(자료전체개수-1)/2+1]) , (원소[정렬된자료,자료전체개수/2]+원소[정렬된자료,자료전체개수/2+1])/2 ]**
#
#     **판단3="따라서, 중앙값은 "자료중앙값 " 이다."**
#
#     입력하여 판단3이라는 텍스트를 만든다.
#
#
#
#
#
# 09. 자료의 개수가 홀수이면 가운데 위치한 값이 중앙값이 됨을 확인한다.

# %% [markdown]
# 10. 입력창에
#
#     **자료={2, 18, 22, 28}**
#
#    ** 입력하여 기본 자료의 바꾼다.**
#
# 11. 자료의 개수가 짝수이면 가운데 위치한 두 값의 평균이 중앙값이 됨을 확인한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12. 입력창에
#
#     **자료평균=평균[자료]**
#
#     입력한다.
#
#
#
# 13. 자료평균과 자료중앙값을 비교해본다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14. 입력창에
#
#     **Geogebra의중앙값함수=중앙값[자료]**
#
#
#
# 15. Geogebra에도 중앙값 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성함.
#
#
#
#
#
# ex)
#
# **자료={3, 7, 5, 4, 1, 9}**
#
# **자료={24, 151, 135, 146, 122}**
#
# **자료={36, 55, 49, 7, 28, 40}**
#
# **자료={86, 88, 74, 92, 80, 105, 102, 95, 89, 96, 120, 201, 113, 107, 97}**
