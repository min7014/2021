# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2021/blob/main/2021030301.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 작성중

# %% [markdown]
# # [최빈값 구하기(Finding The Mode)](https://min7014.github.io/math20210303001.html)

# %% [markdown]
# ### [참고]
# Geogebra와 수학의 시각화 책의 가상주사위 만들기를 참고하여 수업에 실제 적용함.
#
# [Geogebra와 수학의 시각화](https://www.geogebra.org/m/gsARCQs5)

# %% [markdown]
# **[영문버전]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     **첫번째 아래방향 --> Sort by --> Construction order**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. Input 에
#
#     **Data={5,28,28,29,29,30,31,31,32}**
#
#     입력하여 Data라는 list를 만든다.
#
# 04. Input 에
#
#     **SortedData=Sort[Data]**
#
#     입력하여 Data를 오름차순으로 정렬한 SortedData라는  list를 만든다.
#
#
#
# 05. Input 에
#
#     **TotalNumberOfData=CountIf[x==x,Data]**
#
#     입력하여 TotalNumberOfData라는 수를 만든다.
#
#
#
# 06. Input 에
#
#     **Judgement1=If[Mod[TotalNumberOfData,2]==1,"Since the number of Data is odd " ,"Since the number of Data is even"]**
#
#     입력하여 Judgement1이라는 Text를 만든다.
#
#
#
# 07. Input 에
#
#     **Judgement2=If[Mod[TotalNumberOfData,2]==1, ((TotalNumberOfData-1)/2+1) "th number ", "The average of the " (TotalNumberOfData/2) "nd and " (TotalNumberOfData/2+1) "rd numbers "] "in the SortedData(sorted Data) is the median."**
#
#     입력하여 Judgement2라는 Text를 만든다.
#
#
#
# 08. Input 에
#
#     **MedianData=If[Mod[TotalNumberOfData,2]==1, (Element[SortedData,(TotalNumberOfData-1)/2+1]) ,(Element[SortedData,TotalNumberOfData/2]+Element[SortedData,TotalNumberOfData/2+1])/2 ]**
#
#     **Judgement3="Therefore, the median value is " MedianData "."**
#
#     입력하여 MedianData라는 수와 Judgement3이라는 Text를 만든다.
#
# 09. Data의 개수가 홀수이면 가운데 위치한 값이 중앙값이 됨을 확인한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10. Input에
#
#     **Data={2, 18, 22, 28}**
#
#    ** 입력하여 기본 자료의 바꾼다.**
#
# 11. 자료의 개수가 짝수이면 가운데 위치한 두 값의 평균이 중앙값이 됨을 확인한다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12. Input에
#
#     **DataAverage=mean[Data]**
#
#     입력한다.
#
#
#
# 13. DataAverage과 MedianData를 비교해 본다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14. Input에
#
#     **MedianFunctionOfGeogebra=Median[Data]**
#
# 15. Geogebra에도 중앙값 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성함.

# %% [markdown]
# ex)
#
#   **Data={3, 7, 5, 4, 1, 9}**
#
#   **Data={24, 151, 135, 146, 122}**
#
#   **Data={36, 55, 49, 7, 28, 40}**
#
#   **Data={86, 88, 74, 92, 80, 105, 102, 95, 89, 96, 120, 201, 113, 107, 97}**

# %% [markdown]
# **[한글버전]**

# %% [markdown]
# 최빈값은  자료의 값의 도수가 모두 같을 때, 최빈값은 없고 자료의 값의 도수가 모두 같지 않을 때, 도수가 가장 큰 값이 한 개 이상 있으면 그 값이 모두 최빈값이다.
#
#
#
# 01. Geogebra를 실행시킨다.
#
#
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     첫번째 아래방향을 선택 --> 정렬기준 --> 구성순서를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 02. 입력창에
#
#     **자료={85, 95, 90, 95, 85, 95, 100, 90}**
#
#     입력하여 자료라는 리스트를 만든다.
#
#
#
# 03. 입력창에
#
#     **정렬자료=정렬[자료]**
#
#    입력하여 자료를 오름차순으로 정렬한 정렬자료라는  리스트를 만든다.
#
#
#
# 04. 입력창에
#
#     **반복제거된정렬자료=반복원소제거[정렬자료]**
#
#     입력하여 반복제거된정렬자료라는 리스트를 만든다.
#
#
#
# 05. 입력창에
#
#     **반복제거된정렬자료전체개수=세기조건[x==x, 반복제거된정렬자료]**
#
#     입력하여 반복제거정렬자료전체수라는 수를 만든다.
#
#
#
# 06. 입력창에
#
#     **각값의도수=수열[세기조건[x==원소[반복제거된정렬자료,t],자료],t,1,반복제거된정렬자료전체개수]**
#
#     입력하여 e각값의도수라는 리스트를 만든다.
#
#
#
# 07. 입력창에
#
#     **도수의최댓값=최댓값[각값의도수]**
#
#     입력하여 도수의최댓값이라는 수를 만든다.
#
#
#
# 08. 입력창에
#
#     **최댓값도수를가지는자료=미정의삭제[수열[조건[원소[각값의도수,t]==도수의최댓값,원소[반복제거된정렬자료,t]],t,1,반복제거된정렬자료전체개수]]**
#
#     입력하여 최댓값도수를가지는자료라는 리스트를 만든다.
#
#
#
# 09. 입력창에
#
#     **판단1=조건[최댓값도수를가지는자료==반복제거된정렬자료,"최댓값도수를가지는자료와 반복제거된정렬자료가 같으므로","최댓값도수를가지는자료와 반복제거된정렬자료가 다르므로"]**
#
#     입력하여 판단1이라는 텍스트를 만든다.
#
#
#
# 10. 입력창에
#
#     **판단2=조건[최댓값도수를가지는자료==반복제거된정렬자료,"최빈값이 없다.",최댓값도수를가지는자료 "의 원소가 최빈값이다."]**
#
#     입력하여 판단2라는 텍스트를 만든다.
#
#
#
# 11. 입력창에
#
#     **자료평균=평균[자료]**
#
#     입력한다.
#
#
#
# 12. 입력창에
#
#     **Geogebra의최빈값함수=최빈값[자료]**
#
#     에러가 나는 경우가 간혹 있는데 버젼이 다른 경우 에러가 나기도 합니다.
#
#     이런경우 아래 명령어 즉, 최빈값 대신 최빈수 를 입력하기 바랍니다.
#
#     **Geogebra의최빈값함수=최빈수[자료]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13. Goegebra에도 최빈값 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성했으며
#
#     Geogebra에서는 최빈값이 리스트로 나타난다.
#
#     그 이유는 최빈값의 정의에서 한 개 이상이 모두 최빈값이 되는 경우가 있기 때문일 것이다.
#
#     단, 자료의 값의 도수가 모두 같을 때는 정의에서는 최빈값이 없지만,
#
#     Geogebra에서는 도수가 1보다 큰 수로 모두 같은 경우 최빈값 명령어를 사용하였을 때
#
#     모든 값이 최빈값으로 나오는 것을 주의 해야 한다.
#
# |Geogebra 입력|Geogebra 출력|최빈값|
# |------|---|---|
# |자료={2, 4, 3, 5, 2, 2} |	Geogebra의최빈값함수={ 2 }|2|
# |자료={35, 20, 45, 45, 20, 35} |Geogebra의최빈값함수={ 20, 35, 45 }|없다|
# |자료={6, 7, 6, 8, 7 ,9}|Geogebra의최빈값함수={ 6, 7 }|6,7|
#
# ex)
#
# 자료={44, 55, 77, 44, 55, 66, 55, 66}
#
# 자료={125, 130, 110, 150, 140, 135, 115, 120}
#
# 자료={20, 15,5, 10, 25, 30, 15, 10}
